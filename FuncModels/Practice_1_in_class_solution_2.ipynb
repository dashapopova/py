# %%
from tqdm.notebook import tqdm

import torch
from torch.utils.data import Dataset, DataLoader


from transformers import AutoTokenizer, AutoModel

from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import pandas as pd

df = pd.read_csv('/content/CommitmentBank-items.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       uID   Verb    Embedding  \
# 0           1     BNC-1  admit  conditional
# 1           2  BNC-1002    say        modal
# 2           3  BNC-1003    say        modal
# 3           4  BNC-1005    say        modal
# 4           5  BNC-1006    say        modal
#
#                                              Context  \
# 0                        Polly had to think quickly.
# 1  Nevertheless, life went on as it always does. ...
# 2  He patted her hand. If he had chosen to, Thoma...
# 3  She could see his distorted image in the slant...
# 4  She glanced around the room, laying her hot fl...
#
#                                               Target  \
# 0  They were still close enough to shore for him ...
# 1   Indeed it could be said that they had prospered.
# 2  He might have said to her that some time in th...
# 3  Of course she could say it was for the childre...
# 4  Robyn swallowed and took a deep breath trying ...
#
#                                               Prompt ModalType MatTense  \
# 0          Polly was not an experienced ocean sailor       NaN   future
# 1  the Kiwi Keith and the Mackenzie houses had pr...        CI  present
# 2  some time in the middle of the nineteenth cent...        AB  present
# 3                            it was for the children        AB   future
# 4                                   it was all right        AB   future
#
#   MatSubjLemma MatSubjPer MatSubjNum  Embedding.1 genre factive  \
# 0          she      third   singular  conditional   BNC      no
# 1           it      third   singular        modal   BNC      no
# 2           he      third   singular        modal   BNC      no
# 3          she      third   singular        modal   BNC      no
# 4          she      third   singular        modal   BNC      no
#
#    mean.noTarget  sd.noTarget      Mean        SD  \
# 0      -0.111111     1.269296  2.000000  0.866025
# 1       1.200000     1.873796  1.875000  0.834523
# 2      -0.250000     0.462910  0.666667  1.154701
# 3       0.636364     1.120065  0.875000  0.991031
# 4      -1.090909     1.044466  0.000000  2.309401
#
#                               Reponses
# 0            2, 3, 3, 1, 3, 1, 2, 1, 2
# 1               2, 1, 3, 1, 2, 2, 3, 1
# 2  2, 0, 1, 0, 0, 3, -1, 0, 1, 0, 0, 2
# 3              2, 1, 0, 1, -1, 1, 1, 2
# 4    3, 1, -2, -3, -3, 3, 2, 1, -1, -1

# %%
df.loc[:, 'nli'] = 'neutral'
df.loc[df.Mean <= -1, 'nli'] = 'contradiction'
df.loc[df.Mean >= 1, 'nli'] = 'entailment'

# %%
df['Content'] = '[CLS] ' + df['Target'] + ' [SEP] ' + df['Prompt'] + ' [SEP]'

# %%
model = AutoModel.from_pretrained("bert-base-uncased")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
device_cuda = torch.device("cuda")
model = model.to(device_cuda)

# %%
def vectorize_dataset_and_return(data):
    res = []
    for batch in tqdm(data):
        toks = tokenizer(batch[0], padding='max_length', truncation=True, return_tensors='pt',
          max_length=64)
        with torch.no_grad():
            model_output = model(**{k: v.to(model.device) for k, v in toks.items()})
        res.append(torch.mean(model_output.last_hidden_state, dim=1))
    res = torch.vstack(res)
    return res.detach().cpu().numpy()

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def __getitem__(self, index):
        row = self.dataframe.iloc[index].to_numpy()
        features = row[1]
        label = row[0]
        return features, label

    def __len__(self):
        return len(self.dataframe)

# %%
data = CustomDataset(dataframe=df[['nli', 'Content']])

# %%
dl = DataLoader(data, batch_size=256, shuffle=False,
                drop_last=False)
x = vectorize_dataset_and_return(dl)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
le = LabelEncoder()
y = le.fit_transform(df['nli'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
clf = MLPClassifier(random_state=1, max_iter=300, verbose=1)
clf.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 1.06894858
# Iteration 2, loss = 0.93872063
# Iteration 3, loss = 0.89908333
# Iteration 4, loss = 0.88017192
# Iteration 5, loss = 0.89069772
# Iteration 6, loss = 0.82934504
# Iteration 7, loss = 0.83720051
# Iteration 8, loss = 0.79555826
# Iteration 9, loss = 0.83834780
# Iteration 10, loss = 0.76441054
# Iteration 11, loss = 0.80113688
# Iteration 12, loss = 0.77691009
# Iteration 13, loss = 0.75188756
# Iteration 14, loss = 0.72574576
# Iteration 15, loss = 0.72135279
# Iteration 16, loss = 0.70353423
# Iteration 17, loss = 0.70872641
# Iteration 18, loss = 0.69312706
# Iteration 19, loss = 0.70438737
# Iteration 20, loss = 0.66631260
# Iteration 21, loss = 0.68399344
# Iteration 22, loss = 0.65926952
# Iteration 23, loss = 0.65028179
# Iteration 24, loss = 0.63730560
# Iteration 25, loss = 0.64620978
# Iteration 26, loss = 0.63201051
# Iteration 27, loss = 0.61276159
# Iteration 28, loss = 0.61516901
# Iteration 29, loss = 0.60885496
# Iteration 30, loss = 0.59651635
# Iteration 31, loss = 0.58317207
# Iteration 32, loss = 0.58252363
# Iteration 33, loss = 0.58029301
# Iteration 34, loss = 0.57262551
# Iteration 35, loss = 0.57000351
# Iteration 36, loss = 0.54980373
# Iteration 37, loss = 0.54079078
# Iteration 38, loss = 0.54331657
# Iteration 39, loss = 0.55699350
# Iteration 40, loss = 0.53678731
# Iteration 41, loss = 0.53242799
# Iteration 42, loss = 0.54602823
# Iteration 43, loss = 0.53967113
# Iteration 44, loss = 0.57849276
# Iteration 45, loss = 0.52198289
# Iteration 46, loss = 0.53350923
# Iteration 47, loss = 0.53249436
# Iteration 48, loss = 0.51828805
# Iteration 49, loss = 0.56781722
# Iteration 50, loss = 0.50916175
# Iteration 51, loss = 0.50493269
# Iteration 52, loss = 0.48487720
# Iteration 53, loss = 0.49255800
# Iteration 54, loss = 0.45505082
# Iteration 55, loss = 0.48381912
# Iteration 56, loss = 0.45377810
# Iteration 57, loss = 0.44475413
# Iteration 58, loss = 0.45412587
# Iteration 59, loss = 0.44807355
# Iteration 60, loss = 0.43001270
# Iteration 61, loss = 0.44018473
# Iteration 62, loss = 0.46002628
# Iteration 63, loss = 0.40630809
# Iteration 64, loss = 0.41831138
# Iteration 65, loss = 0.40966648
# Iteration 66, loss = 0.40362334
# Iteration 67, loss = 0.40291253
# Iteration 231, loss = 0.04060049
# Iteration 232, loss = 0.04315159
# Iteration 233, loss = 0.03889084
# Iteration 234, loss = 0.03805701
# Iteration 235, loss = 0.03684686
# Iteration 236, loss = 0.03569458
# Iteration 237, loss = 0.03525209
# Iteration 238, loss = 0.03435896
# Iteration 239, loss = 0.03390291
# Iteration 240, loss = 0.03345517
# Iteration 241, loss = 0.03317912
# Iteration 242, loss = 0.03474366
# Iteration 243, loss = 0.03355271
# Iteration 244, loss = 0.03246711
# Iteration 245, loss = 0.03204782
# Iteration 246, loss = 0.03143842
# Iteration 247, loss = 0.03097599
# Iteration 248, loss = 0.03083323
# Iteration 249, loss = 0.03180397
# Iteration 250, loss = 0.02986250
# Iteration 251, loss = 0.03112114
# Iteration 252, loss = 0.03554764
# Iteration 253, loss = 0.04096098
# Iteration 254, loss = 0.03459014
# Iteration 255, loss = 0.03491683
# Iteration 256, loss = 0.03223102
# Iteration 257, loss = 0.03501283
# Iteration 258, loss = 0.02939438
# Iteration 259, loss = 0.03035302
# Iteration 260, loss = 0.02791854
# Iteration 261, loss = 0.02735815
# Iteration 262, loss = 0.02662568
# Iteration 263, loss = 0.02737281
# Iteration 264, loss = 0.02753407
# Iteration 265, loss = 0.02649187
# Iteration 266, loss = 0.02565179
# Iteration 267, loss = 0.02501905
# Iteration 268, loss = 0.02490540
# Iteration 269, loss = 0.02457712
# Iteration 270, loss = 0.02433079
# Iteration 271, loss = 0.02445592
# Iteration 272, loss = 0.02414187
# Iteration 273, loss = 0.02381507
# Iteration 274, loss = 0.02394921
# Iteration 275, loss = 0.02373519
# Iteration 276, loss = 0.02301124
# Iteration 277, loss = 0.02247772
# Iteration 278, loss = 0.02235863
# Iteration 279, loss = 0.02252640
# Iteration 280, loss = 0.02400560
# Iteration 281, loss = 0.02281676
# Iteration 282, loss = 0.02348128
# Iteration 283, loss = 0.03274764
# Iteration 284, loss = 0.03742073
# Iteration 285, loss = 0.03976796
# Iteration 286, loss = 0.03455804
# Iteration 287, loss = 0.03089229
# Iteration 288, loss = 0.03251457
# Iteration 289, loss = 0.02923638
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(max_iter=300, random_state=1, verbose=1)

# %%
train_pred = clf.predict(x_train)
test_pred = clf.predict(x_test)

# %%
crep = classification_report(y_train, train_pred, target_names=le.classes_)
print(crep)
# Out:
#                precision    recall  f1-score   support
#
# contradiction       1.00      1.00      1.00       260
#    entailment       1.00      1.00      1.00       272
#       neutral       1.00      1.00      1.00       272
#
#      accuracy                           1.00       804
#     macro avg       1.00      1.00      1.00       804
#  weighted avg       1.00      1.00      1.00       804

# %%
crep = classification_report(y_test, test_pred, target_names=le.classes_)
print(crep)
# Out:
#                precision    recall  f1-score   support
#
# contradiction       0.69      0.77      0.73       126
#    entailment       0.58      0.68      0.63       118
#       neutral       0.64      0.49      0.56       152
#
#      accuracy                           0.64       396
#     macro avg       0.64      0.65      0.64       396
#  weighted avg       0.64      0.64      0.63       396
